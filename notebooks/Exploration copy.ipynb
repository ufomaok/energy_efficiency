# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# EDIT (change wording and add more details):
#
# Exploring univariate and bivariate characteristics of energy efficiency data set to find outliers and distributions through univariate visualizations and explore trends and patterns through bivariate visualizations.

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
#Loading energy efficiency pandas dataframe

df = pd.read_excel('../data/raw/energy_efficiency_file.xlsx')

# %%
#Displaying first 5 rows of data

df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
#Renaming colummn names for clarity on what 'X' values represent

df.rename(columns= {'X1': 'Relative Compactness', 'X2': 'Surface Area', 'X3': 'Wall Area', 'X4':'Roof Area', 'X5': 'Overall Height', 'X6': 'Orientation', 'X7': 'Glazing Area', 'X8': 'Glazing Distribution Area', 'Y1': 'Heating Load', 'Y2': 'Cooling Load'}, inplace = True)
df.head()
# Out:
#    Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                  0.98         514.5      294.0     110.25             7.0
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
#
#    Orientation  Glazing Area  Glazing Distribution Area  Heating Load  \
# 0            2           0.0                          0         15.55
# 1            3           0.0                          0         15.55
# 2            4           0.0                          0         15.55
# 3            5           0.0                          0         15.55
# 4            2           0.0                          0         20.84
#
#    Cooling Load
# 0         21.33
# 1         21.33
# 2         21.33
# 3         21.33
# ...

# %%
#Dropping the Cooling Load (Y2) column, as the only Y variable we'll only be focusing on is Heating Load(Y1)

df.drop('Cooling Load', axis = 1, inplace = True)
df
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                    0.98         514.5      294.0     110.25             7.0
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 4                    0.90         563.5      318.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 763                  0.64         784.0      343.0     220.50             3.5
# 764                  0.62         808.5      367.5     220.50             3.5
# 765                  0.62         808.5      367.5     220.50             3.5
# 766                  0.62         808.5      367.5     220.50             3.5
# 767                  0.62         808.5      367.5     220.50             3.5
#
# ...
